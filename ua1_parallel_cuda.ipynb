# %% [markdown]
# Installing necessary modules and run necessary scripts

# %%
# !! pip install spacy
# !! python -m spacy download en_core_web_sm
# !!pip install sentence-transformers
# Out:
# ['Requirement already satisfied: sentence-transformers in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (2.2.2)',
#  'Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (4.33.0)',
#  'Requirement already satisfied: tqdm in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (4.66.1)',
#  'Requirement already satisfied: torch>=1.6.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (2.0.1)',
#  'Requirement already satisfied: torchvision in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (0.15.2)',
#  'Requirement already satisfied: numpy in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (1.25.2)',
#  'Requirement already satisfied: scikit-learn in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (1.3.0)',
#  'Requirement already satisfied: scipy in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (1.11.2)',
#  'Requirement already satisfied: nltk in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (3.8.1)',
#  'Requirement already satisfied: sentencepiece in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (0.1.99)',
#  'Requirement already satisfied: huggingface-hub>=0.4.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sentence-transformers) (0.16.4)',
#  'Requirement already satisfied: filelock in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.3)',
#  'Requirement already satisfied: fsspec in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.9.0)',
#  'Requirement already satisfied: requests in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)',
#  'Requirement already satisfied: pyyaml>=5.1 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)',
#  'Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.7.1)',
#  'Requirement already satisfied: packaging>=20.9 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)',
#  'Requirement already satisfied: sympy in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from torch>=1.6.0->sentence-transformers) (1.12)',
#  'Requirement already satisfied: networkx in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from torch>=1.6.0->sentence-transformers) (3.1)',
#  'Requirement already satisfied: jinja2 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)',
#  'Requirement already satisfied: colorama in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from tqdm->sentence-transformers) (0.4.6)',
#  'Requirement already satisfied: regex!=2019.12.17 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.8.8)',
#  'Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)',
#  'Requirement already satisfied: safetensors>=0.3.1 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.3)',
#  'Requirement already satisfied: click in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from nltk->sentence-transformers) (8.1.7)',
#  'Requirement already satisfied: joblib in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from nltk->sentence-transformers) (1.3.2)',
#  'Requirement already satisfied: threadpoolctl>=2.0.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from scikit-learn->sentence-transformers) (3.2.0)',
#  'Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from torchvision->sentence-transformers) (10.0.0)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2.0)',
#  'Requirement already satisfied: idna<4,>=2.5 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)',
#  'Requirement already satisfied: certifi>=2017.4.17 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)',
#  'Requirement already satisfied: mpmath>=0.19 in c:\\users\\qyzyr\\onedrive\\documents\\project_nlp\\unsupervised_annotator1\\venv\\lib\\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)']

# %% [markdown]
# Importing modules

# %%
import spacy
from spacy.tokenizer import Tokenizer
from spacy.util import compile_infix_regex
# Load the language model
nlp = spacy.load('en_core_web_sm')

from sentence_transformers import SentenceTransformer

model = SentenceTransformer('distilbert-base-nli-mean-tokens')
from sentence_transformers import SentenceTransformer, util
from typing import List
from transformers import BertTokenizer

# Initialize the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
from collections import namedtuple
CandidateMWE = namedtuple('CandidateMWE',['text','head', 'sentence','self_encode', 'sent_encode'])
CandidateW=namedtuple('CandidateW',['text','lemma', 'self_encode' ])
Term=namedtuple('Term',['text','detected' ])

# %% [markdown]
# creating functions

# %%
def parse_candidates(text:str):   
    # Process the text with spaCy
    doc = nlp(text)
    
    # Extract MWEs (noun phrases) from the text
    mwe_list = []
    single_noun_list=dict()
    candidate_list=[]
    for sent in doc.sents:
        sent_encode=model.encode(sent.text)
        for chunk in doc.noun_chunks:
            is_candidate=False
            word_count=0
            # mwe_list.append(chunk.text)
            if len(chunk.text.split()) > 1:
                noun_appeared=False
                is_candidate=True
                cleared_candidate=''
                for word in chunk:
                    #IGNORING
                    if word.pos_ in ['PUNCT', 'DET']:
                        continue
                    elif word.pos_ not in ['ADJ', 'PROPN', 'NOUN']:
                        is_candidate=False
                        print(f'{chunk.text} is not candidate 1 {word.text} -- {word.pos_}')
                        break
                    elif word.pos_ in ['PROPN', 'NOUN']:
                        noun_appeared=True
                    elif not(not noun_appeared and word.pos_=='ADJ'):
                        is_candidate=False
                        print(f'{chunk.text} is not candidate 2 {word.text} -- {word.pos_}, {noun_appeared}')
                        break
                    cleared_candidate+=' '+word.text
                    word_count+=1
            if is_candidate and word_count>1:
                cleared_candidate.strip()
                candidate_list.append(CandidateMWE(cleared_candidate, chunk.root.text, sent.text, model.encode(cleared_candidate), sent_encode))
                print(f'Added candicate expression: {cleared_candidate}')
            else:
                
                print(f'Added candidate words from : {chunk.text}')    
                for word in chunk:
                    if word.pos_ in ['NOUN', 'PROPN']:
                        single_noun_list[word.text]=  CandidateW(word.text, word.lemma_, model.encode(word.text))
                        print(word.text)    
    return candidate_list, single_noun_list.values()

# %%
def dist(wi_encode, wj_encode)->float:
    return util.pytorch_cos_sim(
        wi_encode,
        wj_encode
    )
def calculate_topic_score(expression_embedding, sentence_embedding)->float:
    """
    Calculate the topic score between a multiword expression and a sentence.

    Args:
        multiword_expression (str): The multiword expression.
        sentence (str): The sentence containing the expression.

    Returns:
        float: The topic score (cosine similarity) between the two embeddings.
    """
    # Load the distilbert-base-nli-mean-tokens model

    # Encode the multiword expression and sentence into embeddings
    # expression_embedding = model.encode(multiword_expression, convert_to_tensor=True)
    # sentence_embedding = model.encode(sentence, convert_to_tensor=True)

    # Calculate cosine similarity between the two embeddings
    similarity_score = util.pytorch_cos_sim(expression_embedding, sentence_embedding)

    # Extract the cosine similarity value from the tensor
    topic_score = similarity_score[0].item()

    return topic_score


def calculate_specificity_score(mw:CandidateMWE, w:List[CandidateW|CandidateMWE])->float:
    """
    Calculate the specificity score (SP) between a multiword expression (mw) and a list of words/multiword expressions (w).

    Args:
        mw (str): The multiword expression.
        w (list of str): The list of words/multiword expressions in the context.

    Returns:
        float: The specificity score (SP).
    """
    # Load the distilbert-base-nli-mean-tokens model
    # Calculate distances between mw and each word/phrase in w
    distances = [dist(mw.self_encode, wi.self_encode) for wi in w if wi.text != mw.text]

    # Calculate the mean of the distances
    specificity_score = sum(distances) / len(w)

    return specificity_score

# %%
def detect_mw_terms(candidate_list, TSP = 0.05, Ttopic = 0.1)->Term:    
    term_mws2 = []
    
    
    temp_candidate = []
    for candidate in candidate_list:
        topic_score = calculate_topic_score(candidate.self_encode, candidate.sent_encode)
        # sp_score=calculate_specificity_score(candidate, mwe_list)
        if topic_score > Ttopic:
            temp_candidate.append(candidate)
            # print(f'Topic score of "{candidate.text}" is {topic_score}')
        else:
            print(f'Excluded by topic score: "{candidate.text}" is {topic_score}')
    for candidate in temp_candidate:
        # topic_score=calculate_topic_score(candidate.self_encode, candidate.sent_encode)
        sp_score = calculate_specificity_score(candidate, temp_candidate)
        if sp_score > TSP:
            term_mws2.append(Term(candidate.text, 'by_score'))
            print(f'Added by specifity score:"{candidate.text}" {sp_score}')
        else:
            
            print(f'Excluded by specifity score:"{candidate.text}" {sp_score}')
    return term_mws2

# %%
def detect_single_noun_terms(term_mws, single_noun_list, subtoken_threshold=4)->Term:    
    term_nouns=[]
    for candidate in single_noun_list:
        #Check if the lemma of the noun is the same as any of the heads of the multiword expressions.
        is_term=False
        lemma_is_head=False
        for term_mw in term_mws:
            if term_mw.head==candidate.lemma:
                is_term=True
                term_nouns.append(Term(candidate.text, 'by_lemma'))
                print(f'"{candidate.text}" is added by lemma: "{candidate.lemma}" is head of "{term_mw}"')
                break
        if is_term:
            continue
        #segment the word using a subword-unit segmentation and a vocabulary trained over a large general purpose corpus.
        subtokens=tokenizer.tokenize(candidate.text)
        if len(subtokens)>subtoken_threshold:
            term_nouns.append(Term(candidate.text, 'by_subtokens'))
            print(f'{candidate.text} is added by subtokens count: {len(subtokens)}')
    return term_nouns

# %% [markdown]
# Calculate metrics(from https://colab.research.google.com/drive/1y9WM3MSAEwvODhMt0cMwJi24XIllrmaY?usp=sharing)

# %%
def calculate_metrics(true_terms, extracted_terms):
    true_positives = len(true_terms.intersection(extracted_terms))
    false_positives = len(extracted_terms.difference(true_terms))
    false_negatives = len(true_terms.difference(extracted_terms))

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

    return precision, recall, f1_score

def compare_sets(extracted_terms, true_terms):
    true_detections = extracted_terms.intersection(true_terms)
    false_gaps = true_terms.difference(extracted_terms)
    false_detections = extracted_terms.difference(true_terms)

    return true_detections, false_gaps, false_detections

# %%
def report(true_terms, extracted_terms):
    # Расчет метрик
    precision, recall, f1_score = calculate_metrics(true_terms, extracted_terms)
    
    print("Precision:", precision) #Точность
    print("Recall:", recall) #Полнота
    print("F1 Score:", f1_score)
    # Выводит списки истинных обнаружений, ложных пропуски и ложных обнаружений
    true_detections, false_gaps, false_detections = compare_sets(extracted_terms, true_terms)
    
    print("Истинные обнаружения:", true_detections)
    print("Ложные пропуски:", false_gaps)
    print("Ложные обнаружения:", false_detections)
    return precision, recall, f1_score, true_detections, false_gaps, false_detections

# %% [markdown]
# Testing in Folder

# %%
import os

folder_name='tests'
# Get a list of all files in the folder
all_files = os.listdir(folder_name)

# Initialize empty lists to store the tuples
file_tuples = []

# Iterate through the files in the folder
for filename in all_files:
    # Check if the file is a test file (starts with "text_")
    if filename.startswith("text_"):
        # Construct the expected result filename by replacing "text_" with "term_"
        result_filename = "term_" + filename[5:]
        
        # Check if the corresponding result file exists in the folder
        if result_filename in all_files:
            # Append the tuple to the list
            file_tuples.append((filename, result_filename))

# %%
file_tuples
# Out:
# [('text_1.txt', 'term_1.txt'), ('text_2.txt', 'term_2.txt')]

# %%
os.chdir(folder_name)
whole_true_terms=[]
whole_extracted_terms=[]
results=[]
for text_file_name, term_file_name in file_tuples:
    print('____________________________________________________________________\n')
    print(f"checking files: {text_file_name}, {term_file_name}")    
    text=''
    with open(text_file_name) as text_file:
        text=text_file.read()
    print('_____________________________FIRST STEP_________________________________________')
    candidate_list, single_noun_list=parse_candidates(text)
    print('_____________________________SECOND STEP___________________________________________________')
    term_mws=detect_mw_terms(candidate_list)
    print('_____________________________THIRD STEP______________________________________________________________')
    term_nouns=detect_single_noun_terms(term_mws, single_noun_list)
    print('____________________________________TESTING__________________________________________________________________')
    extracted_terms=sorted([txt.text.lower() for txt in term_mws+term_nouns])
    with open(term_file_name) as term_file:
        terms_str=term_file.read()
    true_terms=sorted(terms_str.lower().split(', '))

    precision, recall, f1_score, true_detections, false_gaps, false_detections = report(true_terms, extracted_terms)
    results.append((true_terms, extracted_terms, precision, recall, f1_score, true_detections, false_gaps, false_detections ))
    print('____________________________________________________________________\n')
    whole_true_terms+=true_terms
    whole_extracted_terms=extracted_terms
print('___________________________TOTAL_________________________________________\n')
whole_true_terms.sort()
whole_extracted_terms.sort()
print('total result')
report(whole_true_terms, whole_extracted_terms)
os.chdir('..')
# Out:
# ____________________________________________________________________
#
# checking files: text_1.txt, term_1.txt
# _____________________________FIRST STEP_________________________________________
# Added candidate words from : Corruption
# Corruption
# our company is not candidate 1 our -- PRON
# Added candidate words from : our company
# company
# ¦
# Preventing corruption is not candidate 1
#  -- SPACE
# Added candidate words from : ¦
# Preventing corruption
# ¦
# corruption
# Added candicate expression:  corporate life
# its central position is not candidate 1 its -- PRON
# Added candidate words from : its central position
# position
# Added candicate expression:  European Union
# Added candidate words from : Belgium
# Belgium
# Added candicate expression:  many years
# Added candicate expression:  firm line
# Added candidate words from : corruption
# corruption
# national and international transactions is not candidate 1 and -- CCONJ
# Added candidate words from : national and international transactions
# transactions
# Added candidate words from : this purpose
# purpose
# Added candicate expression:  major reform
# Added candidate words from : the end
# end
# Added candidate words from : the 1990s
# 1990s
# Added candicate expression:  affected aspects
# both the criminal liability is not candidate 1 both -- CCONJ
# Added candidate words from : both the criminal liability
# liability
# Added candicate expression:  legal persons
# Added candidate words from : the implications
# implications
# fiscal and criminal law is not candidate 1 and -- CCONJ
# Added candidate words from : fiscal and criminal law
# law
# Added candidate words from : action
# action
# Added candidate words from : corruption
# corruption
# Added candidate words from : a priority
# priority
# Added candicate expression:  Belgian government
# its National Security Plan is not candidate 1 its -- PRON
# Added candidate words from : its National Security Plan
# National
# Security
# Plan
# Added candidate words from : Corruption
# Corruption
# Added candicate expression:  various forms
# Added candicate expression:  severe penalties
# Added candidate words from : means
# means
# Added candidate words from : this brochure
# brochure
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : the awareness
# awareness
# Added candidate words from : companies
# companies
# Added candicate expression:  international markets
# Added candidate words from : goods
# goods
# Added candidate words from : services
# services
# Added candidate words from : the consequences
# consequences
# Added candidate words from : corruption
# corruption
# Added candicate expression:  Responsible management
# Added candicate expression:  clear definition
# Added candidate words from : what
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : this brochure
# brochure
# Added candidate words from : the awareness
# awareness
# Added candicate expression:  commercial players
# Added candidate words from : them
# Added candidate words from : the risks
# risks
# their business contacts is not candidate 1 their -- PRON
# Added candidate words from : their business contacts
# business
# contacts
# Added candidate words from : What
# Added candidate words from : corruption
# corruption
# Added candidate words from : Corruption
# Corruption
# Added candidate words from : a manifestation
# manifestation
# Added candidate words from : criminality
# criminality
# Added candidate words from : It
# Added candidate words from : companies
# companies
# Added candidate words from : society
# society
# Added candidate words from : It
# Added candidate words from : distortion
# distortion
# Added candidate words from : competition
# competition
# Added candidate words from : investors
# investors
# Added candicate expression:  further development
# Added candicate expression:  sound companies
# Added candidate words from : Corruption
# Corruption
# morally reprehensible and undermines trust is not candidate 1 morally -- ADV
# Added candidate words from : morally reprehensible and undermines trust
# undermines
# trust
# Added candidate words from : society
# society
# Added candidate words from : democracy
# democracy
# Added candicate expression:  business community
# Added candidate words from : it
# Added candicate expression:  main obstacle
# Added candidate words from : investment
# investment
# Added candicate expression:  certain countries
# Added candicate expression:  longer term
# Added candidate words from : corruption
# corruption
# Added candidate words from : costs
# costs
# Added candidate words from : the community
# community
# Added candidate words from : companies
# companies
# Added candidate words from : it
# Added candidate words from : a deterioration
# deterioration
# Added candidate words from : quality
# quality
# Added candidate words from : safety
# safety
# a natural or a legal person is not candidate 1 or -- CCONJ
# Added candidate words from : a natural or a legal person
# person
# Added candidate words from : corruption
# corruption
# Added candidate words from : the soliciting
# soliciting
# Added candidate words from : acceptance
# acceptance
# Added candidate words from : receipt
# receipt
# Added candidate words from : any form
# form
# Added candidate words from : advantage
# advantage
# Added candicate expression:  official context
# Added candidate words from : acceptance
# acceptance
# a given practice is not candidate 1 given -- VERB
# Added candidate words from : a given practice
# practice
# Added candidate words from : behaviour
# behaviour
# Added candidate words from : It
# Added candidate words from : the offering
# offering
# Added candidate words from : granting
# granting
# Added candicate expression:  such advantage
# Added candidate words from : a person
# person
# Added candicate expression:  such behaviour
# Added candidate words from : The law
# law
# Added candicate expression:  Belgian individuals
# Added candidate words from : companies
# companies
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : no distinction
# distinction
# national , international and foreign office-holders is not candidate 1 and -- CCONJ
# Added candidate words from : national , international and foreign office-holders
# office
# holders
# Added candidate words from : It
# Added candidate words from : no difference
# difference
# Added candidate words from : the bribery
# bribery
# Added candidate words from : place
# place
# Added candidate words from : intermediaries
# intermediaries
# Added candidate words from : the advantage
# advantage
# Added candidate words from : oneself
# Added candicate expression:  third party
# Added candidate words from : It
# Added candidate words from : it
# Added candidate words from : the public
# public
# Added candicate expression:  private sector
# Both the person is not candidate 1 Both -- CCONJ
# Added candidate words from : Both the person
# person
# Added candicate expression:  such advantages
# Added candidate words from : the recipient
# recipient
# Added candidate words from : corruption
# corruption
# Added candicate expression:  Belgian law
# both private and public bribery is not candidate 1 both -- CCONJ
# Added candidate words from : both private and public bribery
# bribery
# both active and passive bribery is not candidate 1 both -- CCONJ
# Added candidate words from : both active and passive bribery
# bribery
# Added candicate expression:  other words
# Added candidate words from : corruption
# corruption
# Added candicate expression:  various levels
# Added candicate expression:  various forms
# Added candidate words from : All these forms
# forms
# Added candidate words from : corruption
# corruption
# Added candicate expression:  criminal offences
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : fact
# fact
# Added candicate expression:  incidental condition
# Added candicate expression:  private corruption
# Added candidate words from : it
# Added candidate words from : place
# place
# Added candicate expression:  prior knowledge
# Added candidate words from : the authorisation
# authorisation
# Added candidate words from : the case
# case
# Added candidate words from : directors
# directors
# Added candicate expression:  general assembly
# Added candicate expression:  Belgian Criminal Code
# two chapters is not candidate 1 two -- NUM
# Added candidate words from : two chapters
# chapters
# Added candidate words from : importance
# importance
# Added candidate words from : corruption
# corruption
# Added candidate words from : They
# Added candicate expression:  Criminal Code Articles
# 246 ff is not candidate 1 246 -- NUM
# Added candidate words from : 246 ff
# ff
# Added candidate words from : .
# .
# Added candidate words from : which
# Added candicate expression:  public bribery
# Added candidate words from : 504bis
# 504bis
# Added candidate words from : ter
# ter
# Added candicate expression:  private bribery
# Added candidate words from : Penalties
# Penalties
# six months is not candidate 1 six -- NUM
# Added candidate words from : six months
# months
# three years imprisonment is not candidate 1 three -- NUM
# Added candidate words from : three years imprisonment
# years
# imprisonment
# Added candicate expression:  aggravating circumstances
# Added candicate expression:  custodial sentence
# up to 10 years is not candidate 1 up -- ADV
# Added candidate words from : up to 10 years
# years
# Added candidate words from : Fines
# Fines
# up to 100 000 euros is not candidate 1 up -- ADP
# Added candidate words from : up to 100 000 euros
# euros
# Added candicate expression:  Criminal proceedings
# Added candicate expression:  negative publicity
# Added candicate expression:  legal person
# Added candidate words from : the list
# list
# Added candidate words from : contractors
# contractors
# Added candicate expression:  government contracts
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : companies
# companies
# Added candidate words from : awards
# awards
# Added candicate expression:  public contracts
# Added candidate words from : they
# Added candicate expression:  criminal conspiracy
# Added candidate words from : bribery
# bribery
# Added candidate words from : fraud
# fraud
# Added candicate expression:  money laundering
# Added candicate expression:  other misdemeanour
# Added candidate words from : which
# Added candidate words from : nature
# nature
# Added candidate words from : a violation
# violation
# Added candicate expression:  professional ethics
# Added candicate expression:  Other actions
# Added candidate words from : Article
# Article
# Added candicate expression:  Criminal Code
# Added candidate words from : restriction
# restriction
# Added candidate words from : the freedom
# freedom
# Added candidate words from : bidding
# bidding
# Added candidate words from : registration
# registration
# Added candidate words from : transfers
# transfers
# Added candidate words from : ownership
# ownership
# Added candidate words from : usufruct
# usufruct
# Added candidate words from : leasing
# leasing
# movable or immovable property is not candidate 1 or -- CCONJ
# Added candidate words from : movable or immovable property
# property
# Added candidate words from : a company
# company
# Added candidate words from : a supply
# supply
# 15 days is not candidate 1 15 -- NUM
# Added candidate words from : 15 days
# days
# six months imprisonment is not candidate 1 six -- NUM
# Added candidate words from : six months imprisonment
# months
# imprisonment
# Added candidate words from : a fine
# fine
# 100 to 3000 euros is not candidate 1 100 -- NUM
# Added candidate words from : 100 to 3000 euros
# euros
# Added candicate expression:  tax legislation
# Added candidate words from : each count
# count
# Added candidate words from : corruption
# corruption
# Added candidate words from : prosecution
# prosecution
# Added candicate expression:  Criminal Code
# Added candicate expression:  legal person
# Added candidate words from : the basis
# basis
# Added candicate expression:  tax assessment
# Added candicate expression:  Ex officio
# Added candicate expression:  separate amount
# 309 % is not candidate 1 309 -- NUM
# Added candidate words from : 309 %
# %
# Added candidate words from : the value
# value
# Added candidate words from : the count
# count
# Added candidate words from : corruption
# corruption
# Added candicate expression:  corporate taxpayer
# Plus the statutory ' additional tenths is not candidate 1 Plus -- CCONJ
# Added candidate words from : Plus the statutory ' additional tenths
# tenths
# Added candidate words from : The fine
# fine
# Added candidate words from : the penalty
# penalty
# Added candidate words from : imprisonment
# imprisonment
# Added candidate words from : Article
# Article
# Added candidate words from : the Law
# Law
# 10 February is not candidate 1 10 -- NUM
# Added candidate words from : 10 February
# February
# Added candidate words from : Penalties
# Penalties
# Added candidate words from : Corruption
# Corruption
# Added candicate expression:  Moniteur Belge
# 23 March is not candidate 1 23 -- NUM
# Added candidate words from : 23 March
# March
# Added candidate words from : Article
# Article
# Added candicate expression:  Royal Decree
# 23 November is not candidate 1 23 -- NUM
# Added candidate words from : 23 November
# November
# Added candidate words from : amendment
# amendment
# Added candidate words from : the Law
# Law
# 24 December is not candidate 1 24 -- NUM
# Added candidate words from : 24 December
# December
# Added candicate expression:  Government Contracts
# Added candicate expression:  Certain Contracting
# Added candidate words from : Works
# Works
# Added candidate words from : Supplies
# Supplies
# Added candidate words from : Services
# Services
# Added candicate expression:  Certain Royal Decrees
# Added candidate words from : this Law
# Law
# Added candicate expression:  Moniteur Belge
# 7 December is not candidate 1 7 -- NUM
# Added candidate words from : 7 December
# December
# Plus statutory ' additional tenths is not candidate 1 Plus -- CCONJ
# Added candidate words from : Plus statutory ' additional tenths
# tenths
# Added candidate words from : Article
# Article
# the 1992 Income Tax Law is not candidate 1 1992 -- NUM
# Added candidate words from : the 1992 Income Tax Law
# Income
# Tax
# Law
# Added candidate words from : What
# Added candidate words from : companies
# companies
# Added candidate words from : Corruption
# Corruption
# Added candicate expression:  main barriers
# Added candidate words from : companies
# companies
# Added candicate expression:  foreign markets
# Added candidate words from : the sector
# sector
# Added candidate words from : the country
# country
# Added candidate words from : a chance
# chance
# Added candidate words from : contact
# contact
# Added candicate expression:  corrupt behaviour
# Added candidate words from : It
# Added candidate words from : it
# Added candidate words from : This brochure
# brochure
# Added candidate words from : a number
# number
# Added candidate words from : tips
# tips
# Added candicate expression:  corrupt practices
# Added candidate words from : Codes
# Codes
# Added candidate words from : conduct
# conduct
# Added candidate words from : corruption
# corruption
# its intended purpose is not candidate 1 its -- PRON
# Added candidate words from : its intended purpose
# purpose
# Added candidate words from : the scope
# scope
# Added candidate words from : this prohibition
# prohibition
# Added candidate words from : a market
# market
# Added candidate words from : It
# not only to commission payments is not candidate 1 not -- PART
# Added candidate words from : not only to commission payments
# payments
# Added candidate words from : officials
# officials
# to failure is not candidate 1 to -- PART
# Added candidate words from : to failure
# failure
# Added candicate expression:  such payments
# Added candidate words from : subcontracts
# subcontracts
# Added candicate expression:  consultancy agreements
# Added candidate words from : contracts
# contracts
# Added candicate expression:  technical assistance
# Added candidate words from : Payments
# Payments
# Added candicate expression:  local agents
# Added candidate words from : settlement
# settlement
# lawfully provided services is not candidate 1 lawfully -- ADV
# Added candidate words from : lawfully provided services
# services
# Added candidate words from : The auditing
# auditing
# Added candicate expression:  corporate financial statements
# -transparent or off-books accounting is not candidate 1 or -- CCONJ
# Added candidate words from : -transparent or off-books accounting
# books
# accounting
# Added candidate words from : Compliance
# Compliance
# Added candidate words from : the rules
# rules
# Added candidate words from : funding
# funding
# Added candicate expression:  political parties
# companies ' managerial or controlling organs is not candidate 1 ' -- PART
# Added candidate words from : companies ' managerial or controlling organs
# companies
# organs
# Added candicate expression:  accounting irregularities
# Added candicate expression:  main measures
# Added candicate expression:  good management
# Added candidate words from : codes
# codes
# Added candidate words from : conduct
# conduct
# Added candicate expression:  best signal
# a company 's staff is not candidate 1 's -- PART
# Added candidate words from : a company 's staff
# company
# staff
# Added candidate words from : the example
# example
# its managers is not candidate 1 its -- PRON
# Added candidate words from : its managers
# managers
# Added candidate words from : it
# Added candidate words from : corruption
# corruption
# Added candicate expression:  normal business contacts
# Added candicate expression:  Grey areas
# Added candidate words from : which
# Added candicate expression:  special attention
# Added candicate expression:  awkward situations
# Added candidate words from : Trading
# Trading
# Saddam Hussein 's Iraq is not candidate 1 's -- PART
# Added candidate words from : Saddam Hussein 's Iraq
# Saddam
# Hussein
# Iraq
# Added candicate expression:  serious consequences
# the company 's reputation is not candidate 1 's -- PART
# Added candidate words from : the company 's reputation
# company
# reputation
# Added candicate expression:  criminal law
# Added candidate words from : commission
# commission
# Added candicate expression:  Iraqi officials
# their intermediaries is not candidate 1 their -- PRON
# Added candidate words from : their intermediaries
# intermediaries
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : the bribing
# bribing
# Added candicate expression:  foreign officials
# Added candidate words from : people
# people
# Added candicate expression:  Belgian government department
# Added candidate words from : The OECD
# OECD
# Added candidate words from : ( Organisation
# Organisation
# Added candicate expression:  Economic Cooperation
# Added candidate words from : Development
# Development
# Added candidate words from : assessments
# assessments
# Added candicate expression:  national governments
# the 1997 anti-bribery convention is not candidate 1 1997 -- NUM
# Added candidate words from : the 1997 anti-bribery convention
# convention
# too few companies is not candidate 1 too -- ADV
# Added candidate words from : too few companies
# companies
# Added candicate expression:  good practices
# Added candicate expression:  alarm signals
# Added candidate words from : risks
# risks
# Added candidate words from : That corruption
# corruption
# Added candidate words from : extortion
# extortion
# Added candicate expression:  tactless civil servants
# Added candicate expression:  other persons
# Added candicate expression:  various forms
# Added candidate words from : difficulties
# difficulties
# Added candidate words from : companies
# companies
# the following examples is not candidate 1 following -- VERB
# Added candidate words from : the following examples
# examples
# Added candidate words from : it
# Added candicate expression:  warning signs
# Added candicate expression:  early stage
# Added candidate words from : order
# order
# Added candidate words from : the risks
# risks
# Added candicate expression:  few dollars
# my passport is not candidate 1 my -- PRON
# Added candidate words from : my passport
# passport
# Added candidate words from : I
# Added candidate words from : no risk
# risk
# Added candidate words from : the airport
# airport
# Added candidate words from : the authorities
# authorities
# my papers is not candidate 1 my -- PRON
# Added candidate words from : my papers
# papers
# My Purchasing Director is not candidate 1 My -- PRON
# Added candidate words from : My Purchasing Director
# Purchasing
# Director
# Added candicate expression:  secret agreement
# Added candidate words from : a supplier
# supplier
# Added candidate words from : who
# Added candidate words from : the products
# products
# Added candidate words from : which
# Added candidate words from : I
# my branches is not candidate 1 my -- PRON
# Added candidate words from : my branches
# branches
# two possibilities is not candidate 1 two -- NUM
# Added candidate words from : two possibilities
# possibilities
# Added candidate words from : I
# Added candidate words from : this director
# director
# Added candidate words from : the push
# push
# Added candidate words from : he
# Added candicate expression:  field day
# Added candidate words from : the competition
# competition
# Added candidate words from : I
# Added candicate expression:  legal action
# Added candidate words from : him
# Added candidate words from : fear
# fear
# Added candidate words from : publicity
# publicity
# My company is not candidate 1 My -- PRON
# Added candidate words from : My company
# company
# Added candidate words from : it
# Added candidate words from : the price
# price
# Added candidate words from : I
# Added candidate words from : the consumer
# consumer
# unnecessary and counter-productive commission is not candidate 1 and -- CCONJ
# Added candidate words from : unnecessary and counter-productive commission
# commission
# Added candidate words from : I
# Added candidate words from : the leaders
# leaders
# Added candicate expression:  certain country
# Added candidate words from : something
# Added candidate words from : payments
# payments
# Added candidate words from : the supply
# supply
# Added candidate words from : commodities
# commodities
# Added candidate words from : I
# my colleagues is not candidate 1 my -- PRON
# Added candidate words from : my colleagues
# colleagues
# Added candicate expression:  other countries
# Added candidate words from : them
# Added candidate words from : these practices
# practices
# Added candidate words from : the past
# past
# Added candidate words from : No
# No
# Added candidate words from : me
# Added candidate words from : business
# business
# Added candidate words from : them
# Added candidate words from : I
# Added candicate expression:  sunny destination
# Madrid / Rome / San Francisco is not candidate 1 / -- SYM
# Added candidate words from : Madrid / Rome / San Francisco
# Madrid
# Rome
# San
# Francisco
# Added candidate words from : the director
# director
# Added candicate expression:  public institution
# my latest product launch is not candidate 1 my -- PRON
# Added candidate words from : my latest product launch
# product
# launch
# Added candidate words from : We
# Added candicate expression:  whole week
# Added candidate words from : the tests
# tests
# Added candidate words from : I
# Added candidate words from : him
# Added candidate words from : her
# my new equipment is not candidate 1 my -- PRON
# Added candidate words from : my new equipment
# equipment
# Added candicate expression:  nearest Belgian factory
# Added candidate words from : You
# Added candidate words from : mind
# mind
# Added candicate expression:  possible penalties
# Added candidate words from : addition
# addition
# Added candicate expression:  criminal prosecution
# Added candidate words from : which
# Added candidate words from : you
# Added candidate words from : you
# Added candicate expression:  World Bank
# Added candidate words from : you
# Added candidate words from : a blacklist
# blacklist
# Added candidate words from : companies
# companies
# Added candidate words from : individuals
# individuals
# Added candidate words from : which
# Added candidate words from : it
# Added candidate words from : connection
# connection
# Added candicate expression:  various markets
# Added candidate words from : which
# Added candidate words from : subsidies
# subsidies
# Added candicate expression:  development aid
# Added candicate expression:  European Union
# Added candidate words from : payments
# payments
# Added candidate words from : subsidies
# subsidies
# Added candidate words from : the programme
# programme
# Added candidate words from : which
# Added candidate words from : you
# Added candidate words from : You
# Added candidate words from : that corruption
# corruption
# Added candidate words from : it
# your company is not candidate 1 your -- PRON
# Added candidate words from : your company
# company
# Added candidate words from : you
# Added candidate words from : officials
# officials
# Added candidate words from : this
# Added candidate words from : the temptation
# temptation
# the company 's assets is not candidate 1 's -- PART
# Added candidate words from : the company 's assets
# company
# assets
# Added candidate words from : bribery
# bribery
# individuals ' own fields is not candidate 1 ' -- PART
# Added candidate words from : individuals ' own fields
# individuals
# fields
# Added candidate words from : activity
# activity
# Added candidate words from : The converse
# converse
# Added candidate words from : an example
# example
# Added candicate expression:  ethical behaviour
# Added candidate words from : you
# Added candidate words from : yourself
# Added candidate words from : fraud
# fraud
# Added candidate words from : you
# Added candicate expression:  vulnerable position
# Added candidate words from : no way
# way
# Added candidate words from : it
# Added candicate expression:  slush money
# Added candidate words from : yourself
# Added candidate words from : the event
# event
# Added candicate expression:  commercial dispute
# Added candidate words from : termination
# termination
# Added candidate words from : a contract
# contract
# Added candidate words from : it
# Added candidate words from : amounts
# amounts
# Added candidate words from : which
# Added candidate words from : law
# law
# Added candidate words from : action
# action
# Added candidate words from : what
# Added candidate words from : a company
# company
# Added candidate words from : practice
# practice
# Added candidate words from : yourself
# Added candicate expression:  good start
# Added candidate words from : Information
# Information
# the first and best weapon is not candidate 1 and -- CCONJ
# Added candidate words from : the first and best weapon
# weapon
# Added candidate words from : the effort
# effort
# Added candidate words from : which
# Added candidate words from : companies
# companies
# Added candicate expression:  corrupt business practices
# Added candidate words from : This brochure
# brochure
# some Belgian and international websites is not candidate 1 and -- CCONJ
# Added candidate words from : some Belgian and international websites
# websites
# Added candidate words from : which
# Added candidate words from : this information
# information
# Added candidate words from : example
# example
# Added candidate words from : a look
# look
# Added candicate expression:  ICC Rules
# Added candidate words from : Conduct
# Conduct
# Added candidate words from : Recommendations
# Recommendations
# Added candidate words from : Extortion
# Extortion
# Added candidate words from : Bribery
# Bribery
# Added candidate words from : the ICC
# ICC
# an employers ' organization is not candidate 1 ' -- PART
# Added candidate words from : an employers ' organization
# employers
# organization
# Added candidate words from : These
# Added candidate words from : a method
# method
# Added candidate words from : self-regulation
# self
# regulation
# Added candidate words from : which
# Added candicate expression:  basic rules
# Added candidate words from : prevention
# prevention
# Added candidate words from : corruption
# corruption
# Added candidate words from : companies
# companies
# Added candidate words from : they
# Added candicate expression:  legal status
# Added candicate expression:  ICC Rules
# Added candidate words from : Conduct
# Conduct
# the most sound business practices is not candidate 1 most -- ADV
# Added candidate words from : the most sound business practices
# business
# practices
# Added candidate words from : These Rules
# Rules
# Added candidate words from : Conduct
# Conduct
# Added candidate words from : it
# Added candidate words from : companies
# companies
# their statutory obligations is not candidate 1 their -- PRON
# Added candidate words from : their statutory obligations
# obligations
# Added candidate words from : responsibilities
# responsibilities
# Added candidate words from : The ICC
# ICC
# Added candicate expression:  important tool
# its disposal is not candidate 1 its -- PRON
# Added candidate words from : its disposal
# disposal
# Fighting Corruption is not candidate 1 Fighting -- VERB
# Added candidate words from : Fighting Corruption
# Corruption
# Added candicate expression:  International Corporate Integrity Handbook
# Added candicate expression:  ICC publication
# Added candidate words from : No
# No
# Added candidate words from : .
# .
# 2008 edition is not candidate 1 2008 -- NUM
# Added candidate words from : 2008 edition
# edition
# Added candicate expression:  international companies
# Added candicate expression:  ICC Rules
# the 1997 OECD Convention is not candidate 1 1997 -- NUM
# Added candidate words from : the 1997 OECD Convention
# OECD
# Convention
# Added candidate words from : Bribery
# Bribery
# Added candicate expression:  Foreign Public Officials
# Added candicate expression:  International Business Transactions
# Added candidate words from : The ICC
# ICC
# Added candidate words from : Belgium
# Belgium
# French and Dutch versions is not candidate 1 and -- CCONJ
# Added candidate words from : French and Dutch versions
# versions
# Added candidate words from : a brochure
# brochure
# Added candicate expression:  corruptie voorkomen
# Added candidate words from : ©venir
# ©
# venir
# Added candidate words from : The brochure
# brochure
# Added candicate expression:  practical guide
# Added candidate words from : businesses
# businesses
# attempted corruption is not candidate 1 attempted -- VERB
# Added candidate words from : attempted corruption
# corruption
# Its suggestions is not candidate 1 Its -- PRON
# Added candidate words from : Its suggestions
# suggestions
# Added candidate words from : companies
# companies
# Added candidate words from : a code
# code
# Added candidate words from : conduct
# conduct
# their employees is not candidate 1 their -- PRON
# Added candidate words from : their employees
# employees
# Added candidate words from : it
# Added candidate words from : The website
# website
# Added candidate words from : the NGO
# NGO
# Added candicate expression:  Transparency International
# Added candidate words from : examples
# examples
# Added candicate expression:  corporate initiatives
# Added candidate words from : corruption
# corruption
# Added candicate expression:  Transparency International Business Principles
# Added candicate expression:  major international companies
# Added candicate expression:  SME edition
# small and medium-sized enterprises11 is not candidate 1 and -- CCONJ
# Added candidate words from : small and medium-sized enterprises11
# enterprises11
# Added candicate expression:  Belgian Network
# Added candicate expression:  Transparency International
# Added candidate words from : courses
# courses
# Added candidate words from : advice
# advice
# Added candidate words from : corruption
# corruption
# Added candicate expression:  invaluable source
# Added candidate words from : information
# information
# Added candicate expression:  Fighting Corruption
# Added candicate expression:  Collective Action Guide
# Added candidate words from : the website
# website
# Added candicate expression:  World Bank
# Added candidate words from : action
# action
# Added candidate words from : It
# Added candidate words from : the fight
# fight
# Added candidate words from : corruption
# corruption
# Added candidate words from : action
# action
# Added candidate words from : reactive
# reactive
# Added candidate words from : strategy
# strategy
# Added candidate words from : corruption
# corruption
# your department is not candidate 1 your -- PRON
# Added candidate words from : your department
# department
# Added candidate words from : company
# company
# Added candidate words from : What
# your weak points is not candidate 1 your -- PRON
# Added candidate words from : your weak points
# points
# what front is not candidate 1 what -- PRON
# Added candidate words from : what front
# front
# Added candidate words from : you
# Added candidate words from : risks
# risks
# Added candidate words from : you
# Added candidate words from : you
# Added candicate expression:  delicate situations
# Added candidate words from : you
# Added candicate expression:  sound decisions
# Added candicate expression:  sufficient time
# Added candidate words from : reflection
# reflection
# Added candicate expression:  crisis situation
# Your measures is not candidate 1 Your -- PRON
# Added candidate words from : Your measures
# measures
# your company 's size is not candidate 1 your -- PRON
# Added candidate words from : your company 's size
# company
# size
# Added candidate words from : the degree
# degree
# its exposure is not candidate 1 its -- PRON
# Added candidate words from : its exposure
# exposure
# Added candicate expression:  such risk countries
# Added candidate words from : sectors
# sectors
# Added candidate words from : you
# Added candidate words from : all areas
# areas
# your small business is not candidate 1 your -- PRON
# Added candidate words from : your small business
# business
# Added candidate words from : the risk
# risk
# Added candidate words from : you
# corruption-related issues is not candidate 1 related -- VERB
# Added candidate words from : corruption-related issues
# corruption
# issues
# Added candidate words from : you
# Added candidate words from : the awareness
# awareness
# your staff is not candidate 1 your -- PRON
# Added candidate words from : your staff
# staff
# Added candidate words from : Ways
# Ways
# Added candidate words from : this
# Added candidate words from : codes
# codes
# conduct and transparent procurement and market procedures is not candidate 1 and -- CCONJ
# Added candidate words from : conduct and transparent procurement and market procedures
# conduct
# procurement
# market
# procedures
# Added candicate expression:  Other methods
# Added candidate words from : posts
# posts
# Added candidate words from : which
# Added candicate expression:  corruption risks
# Added candicate expression:  screen candidates
# Added candidate words from : these
# Added candicate expression:  regular integrity courses
# your staff is not candidate 1 your -- PRON
# Added candidate words from : your staff
# staff
# your staff is not candidate 1 your -- PRON
# Added candidate words from : your staff
# staff
# Added candicate expression:  adequate salary
# Added candicate expression:  future trends
# Added candidate words from : You
# Added candidate words from : a checklist
# checklist
# Added candidate words from : risks
# risks
# Added candidate words from : bribery
# bribery
# your company 's business is not candidate 1 your -- PRON
# Added candidate words from : your company 's business
# company
# business
# Added candidate words from : a manual
# manual
# Added candicate expression:  best practices
# Added candidate words from : a code
# code
# Added candidate words from : conduct
# conduct
# Added candicate expression:  powerful tool
# Added candidate words from : corruption
# corruption
# Added candicate expression:  systematic protection
# Added candidate words from : people
# people
# Added candidate words from : who
# Added candidate words from : facts
# facts
# your company is not candidate 1 your -- PRON
# Added candidate words from : your company
# company
# Added candicate expression:  main NGO
# Added candidate words from : corruption
# corruption
# aptly enough - transparency International is not candidate 1 aptly -- ADV
# Added candidate words from : aptly enough - transparency International
# transparency
# International
# Added candidate words from : Corruption
# Corruption
# Added candicate expression:  closed doors
# Added candidate words from : That
# Added candicate expression:  clear procedures
# Added candidate words from : the principle
# principle
# Added candidate words from : double-checking
# checking
# Added candidate words from : Rotation
# Rotation
# the most exposed positions is not candidate 1 most -- ADV
# Added candidate words from : the most exposed positions
# positions
# the established procedures is not candidate 1 established -- VERB
# Added candidate words from : the established procedures
# procedures
# your set rules is not candidate 1 your -- PRON
# Added candidate words from : your set rules
# rules
# Added candicate expression:  good management
# Added candidate words from : they
# Added candidate words from : practice
# practice
# your efforts is not candidate 1 your -- PRON
# Added candidate words from : your efforts
# efforts
# Added candidate words from : problems
# problems
# Added candidate words from : help
# help
# Added candidate words from : advice
# advice
# the established channels is not candidate 1 established -- VERB
# Added candidate words from : the established channels
# channels
# your trade organization is not candidate 1 your -- PRON
# Added candidate words from : your trade organization
# trade
# organization
# your trade union is not candidate 1 your -- PRON
# Added candidate words from : your trade union
# trade
# union
# Added candidate words from : the Federation
# Federation
# Added candidate words from : Enterprises
# Enterprises
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : FEB
# FEB
# Added candidate words from : the Chamber
# Chamber
# Added candidate words from : Commerce
# Commerce
# Added candidate words from : the ( police
# police
# Added candidate words from : ) authorities
# authorities
# your co is not candidate 1 your -- PRON
# Added candidate words from : your co
# co
# Added candidate words from : -
# -
# Added candidate words from : operation
# operation
# Added candidate words from : us
# Added candidate words from : The departments
# departments
# Added candidate words from : government
# government
# Added candidate words from : the fight
# fight
# Added candidate words from : corruption
# corruption
# Added candidate words from : What
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : corruption
# corruption
# Added candicate expression:  international level
# Added candidate words from : The internationalization
# internationalization
# Added candidate words from : trade
# trade
# Added candidate words from : the expansion
# expansion
# Added candicate expression:  European Union
# growing realization is not candidate 1 growing -- VERB
# Added candidate words from : growing realization
# realization
# Added candidate words from : corruption
# corruption
# Added candidate words from : a phenomenon
# phenomenon
# Added candidate words from : which
# Added candidate words from : That
# Added candidate words from : support
# support
# Added candicate expression:  Community rules
# Added candidate words from : which
# Added candicate expression:  cross - border approach
# Added candidate words from : corruption
# corruption
# Added candidate words from : This
# Added candidate words from : penalties
# penalties
# one 's own national officials is not candidate 1 one -- PRON
# Added candidate words from : one 's own national officials
# officials
# Added candidate words from : persons
# persons
# Added candidate words from : companies
# companies
# Added candidate words from : corruption
# corruption
# Added candicate expression:  foreign officials
# Added candicate expression:  Belgian companies
# Added candidate words from : which
# Added candicate expression:  international market
# Added candicate expression:  corrupt behaviour
# domestic or international trade is not candidate 1 or -- CCONJ
# Added candidate words from : domestic or international trade
# trade
# Added candidate words from : They
# Added candidate words from : they
# Added candicate expression:  corrupt practices
# Added candicate expression:  main international initiatives
# Added candidate words from : processes
# processes
# Added candicate expression:  United Nations Convention
# Added candidate words from : Corruption
# Corruption
# 31 October is not candidate 1 31 -- NUM
# Added candidate words from : 31 October
# October
# Added candidate words from : force
# force
# Added candidate words from : December
# December
# Added candidate words from : This
# Added candicate expression:  first global instrument
# Added candidate words from : the fight
# fight
# Added candidate words from : corruption
# corruption
# Added candidate words from : It
# Added candidate words from : provisions
# provisions
# Added candicate expression:  preventive measures
# Added candidate words from : the penalization
# penalization
# Added candidate words from : corruption
# corruption
# Added candicate expression:  international co
# Added candidate words from : -
# -
# Added candidate words from : operation
# operation
# Added candicate expression:  technical support
# Added candidate words from : The Convention
# Convention
# Added candicate expression:  broad support
# more than 100 member-countries is not candidate 1 than -- ADP
# Added candidate words from : more than 100 member-countries
# member
# countries
# Added candidate words from : it
# Added candidate words from : Belgium
# Belgium
# Added candicate expression:  United Nations Global Compact
# nearly 5000 companies is not candidate 1 nearly -- ADV
# Added candidate words from : nearly 5000 companies
# companies
# Added candidate words from : organizations
# organizations
# Added candidate words from : the world
# world
# Their members is not candidate 1 Their -- PRON
# Added candidate words from : Their members
# members
# Added candidate words from : principles
# principles
# Added candidate words from : the fields
# fields
# Added candicate expression:  human rights
# Added candidate words from : corruption
# corruption
# their activities is not candidate 1 their -- PRON
# Added candidate words from : their activities
# activities
# Added candidate words from : strategies
# strategies
# Added candidate words from : The members
# members
# Added candidate words from : the implementation
# implementation
# Added candidate words from : these principles
# principles
# Added candicate expression:  Belgian network
# Added candidate words from : Europe
# Europe
# Added candidate words from : Corruption
# Corruption
# Added candidate words from : provisions
# provisions
# both active and passive corruption is not candidate 1 both -- CCONJ
# Added candidate words from : both active and passive corruption
# corruption
# the public and private sectors is not candidate 1 and -- CCONJ
# Added candidate words from : the public and private sectors
# sectors
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : this Convention
# Convention
# Added candidate words from : GRECO
# GRECO
# Added candidate words from : the Group
# Group
# Added candidate words from : States
# States
# Added candidate words from : Corruption
# Corruption
# Added candidate words from : which
# Added candidate words from : application
# application
# Added candidate words from : the Convention
# Convention
# Added candicate expression:  Member States
# Added candidate words from : Europe
# Europe
# Added candidate words from : Corruption
# Corruption
# , likewise of 1999 , deals is not candidate 1 likewise -- ADV
# Added candidate words from : , likewise of 1999 , deals
# deals
# Added candicate expression:  civil aspects
# Added candidate words from : corruption
# corruption
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : this Convention
# Convention
# The 1997 OECD Convention is not candidate 1 1997 -- NUM
# Added candidate words from : The 1997 OECD Convention
# OECD
# Convention
# Added candidate words from : Bribery
# Bribery
# Added candicate expression:  Foreign Public Officials
# Added candicate expression:  International Business Transactions
# Belgium 's private sector is not candidate 1 's -- PART
# Added candidate words from : Belgium 's private sector
# Belgium
# sector
# Added candidate words from : The aim
# aim
# Added candicate expression:  OECD Convention
# Added candicate expression:  common framework
# Added candicate expression:  level playing field
# Added candidate words from : companies
# companies
# Added candidate words from : the countries
# countries
# Added candidate words from : which
# Added candidate words from : the Convention
# Convention
# Added candidate words from : The Convention
# Convention
# Added candicate expression:  active corruption
# Added candidate words from : It
# Added candidate words from : people
# people
# Added candidate words from : who
# Added candicate expression:  foreign official
# Added candidate words from : countries
# countries
# Added candidate words from : which
# Added candidate words from : the Convention
# Convention
# Added candicate expression:  strict evaluation mechanism
# Added candidate words from : the OECD
# OECD
# Added candidate words from : which
# Added candidate words from : the countries
# countries
# Added candidate words from : implementation
# implementation
# Added candidate words from : enforcement
# enforcement
# Added candidate words from : the Convention
# Convention
# Added candicate expression:  OECD Guidelines
# Added candicate expression:  Multinational Enterprises
# Added candidate words from : recommendations
# recommendations
# Added candidate words from : companies
# companies
# Added candidate words from : a view
# view
# socially responsible action is not candidate 1 socially -- ADV
# Added candidate words from : socially responsible action
# action
# Added candidate words from : They
# Added candidate words from : a number
# number
# Added candicate expression:  voluntary principles
# Added candidate words from : standards
# standards
# Added candicate expression:  responsible behaviour
# Added candicate expression:  business relations
# Added candicate expression:  European Union
# two directives is not candidate 1 two -- NUM
# Added candidate words from : two directives
# directives
# 2004 / 17 / EC is not candidate 1 2004 -- NUM
# Added candidate words from : 2004 / 17 / EC
# EC
# 2004 / 18 / EC is not candidate 1 2004 -- NUM
# Added candidate words from : 2004 / 18 / EC
# EC
# Added candidate words from : corruption
# corruption
# Added candidate words from : the consequences
# consequences
# Added candidate words from : corruption
# corruption
# Added candidate words from : Businesses
# Businesses
# Added candidate words from : which
# Added candidate words from : bribery
# bribery
# Added candidate words from : participation
# participation
# Added candicate expression:  public invitations
# Added candicate expression:  other countries
# Added candidate words from : A number
# number
# Added candicate expression:  EU Member States
# Added candidate words from : blacklists
# blacklists
# Added candidate words from : relation
# relation
# Added candicate expression:  public contracts
# Added candicate expression:  Other international regulations
# Added candidate words from : initiatives
# initiatives
# Added candicate expression:  foreign legislation
# Added candicate expression:  Belgian companies
# Added candicate expression:  Noteworthy initiatives
# Added candidate words from : this regard
# regard
# the World Bank 's Collective Action initiative is not candidate 1 's -- PART
# Added candidate words from : the World Bank 's Collective Action initiative
# World
# Bank
# Collective
# Action
# initiative
# Added candidate words from : www.fightingcorruption.org
# www.fightingcorruption.org
# the 1996 WTO Agreement is not candidate 1 1996 -- NUM
# Added candidate words from : the 1996 WTO Agreement
# WTO
# Agreement
# Added candicate expression:  Government Procurement
# Added candidate words from : ( GPA
# GPA
# the USA 's Foreign Corrupt Practices Act is not candidate 1 's -- PART
# Added candidate words from : the USA 's Foreign Corrupt Practices Act
# USA
# Foreign
# Corrupt
# Practices
# Act
# Added candicate expression:  Belgian companies
# Added candicate expression:  latter US legislation
# Added candidate words from : example
# example
# Added candidate words from : they
# Added candicate expression:  American company
# Added candidate words from : part
# part
# Added candicate expression:  joint venture
# Added candicate expression:  national level
# Added candicate expression:  late 1990s
# Added candidate words from : Belgium
# Belgium
# increasing attention is not candidate 1 increasing -- VERB
# Added candidate words from : increasing attention
# attention
# its anti-corruption policy is not candidate 1 its -- PRON
# Added candidate words from : its anti-corruption policy
# policy
# Added candidate words from : A number
# number
# Added candicate expression:  national corruption scandals
# Added candicate expression:  inadequate legal means
# Added candidate words from : them
# Added candidate words from : Belgium
# Belgium
# its penalties is not candidate 1 its -- PRON
# Added candidate words from : its penalties
# penalties
# Added candidate words from : bribery
# bribery
# Added candicate expression:  International pressure
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : the conventions
# conventions
# ...
# framework
# Added candicate expression:  public trust
# Added candicate expression:  proper functioning
# Added candicate expression:  Federal Civil Service
# Added candicate expression:  civil servants
# Added candidate words from : accordance
# accordance
# Added candicate expression:  good practice
# Added candicate expression:  private sector
# its own efforts is not candidate 1 its -- PRON
# Added candidate words from : its own efforts
# efforts
# Added candicate expression:  recent years
# Added candidate words from : Examples
# Examples
# Added candicate expression:  unremitting work
# Added candidate words from : organizations
# organizations
# Added candidate words from : the FEB
# FEB
# Added candicate expression:  Belgian Network
# Transparency International and ICC Belgium is not candidate 1 and -- CCONJ
# Added candidate words from : Transparency International and ICC Belgium
# Transparency
# International
# ICC
# Belgium
# companies ' awareness is not candidate 1 ' -- PART
# Added candidate words from : companies ' awareness
# companies
# awareness
# Added candidate words from : these problems
# problems
# Added candidate words from : These organizations
# organizations
# Added candidate words from : companies
# companies
# Added candidate words from : which
# Added candicate expression:  ethical enterprise
# Added candidate words from : a climate
# climate
# Added candidate words from : globalization
# globalization
# Added candicate expression:  inter - departmental working group
# Added candidate words from : the Service
# Service
# Added candicate expression:  Criminal Policy
# Added candidate words from : which
# Added candidate words from : the recommendations
# recommendations
# Added candidate words from : the OECD
# OECD
# Added candidate words from : GRECO
# GRECO
# Added candidate words from : the UN
# UN
# Added candidate words from : corruption
# corruption
# The working group is not candidate 1 working -- VERB
# Added candidate words from : The working group
# group
# Added candicate expression:  main partners
# Added candicate expression:  Belgian anti - corruption policy
# Added candidate words from : a Network
# Network
# Added candidate words from : Expertise
# Expertise
# Added candidate words from : Corruption
# Corruption
# Added candidate words from : the auspices
# auspices
# Added candidate words from : the Board
# Board
# Added candicate expression:  Public Prosecutors General
# Added candidate words from : It
# Added candidate words from : the Network
# Network
# Added candidate words from : Expertise
# Expertise
# Economic , Financial and Fiscal Crime is not candidate 1 and -- CCONJ
# Added candidate words from : Economic , Financial and Fiscal Crime
# Economic
# Financial
# Fiscal
# Crime
# Added candidate words from : partners
# partners
# Added candicate expression:  corruption prosecution policy
# Added candidate words from : any case
# case
# Added candidate words from : a need
# need
# Added candicate expression:  information exchange
# Added candidate words from : contacts
# contacts
# the preventive and reactive arms is not candidate 1 and -- CCONJ
# Added candidate words from : the preventive and reactive arms
# arms
# Added candidate words from : This
# Added candidate words from : place
# place
# a more structured , institutionalized way is not candidate 1 more -- ADV
# Added candidate words from : a more structured , institutionalized way
# way
# Added candidate words from : A bridge
# bridge
# the public and private levels is not candidate 1 and -- CCONJ
# Added candidate words from : the public and private levels
# levels
# Added candicate expression:  private sector
# Added candidate words from : the misdemeanour
# misdemeanour
# Added candidate words from : corruption
# corruption
# Added candidate words from : all kinds
# kinds
# ethically unacceptable behaviour is not candidate 1 ethically -- ADV
# Added candidate words from : ethically unacceptable behaviour
# behaviour
# Added candidate words from : This
# Added candidate words from : a role
# role
# Added candidate words from : which
# Added candicate expression:  public sector
# hence this brochure is not candidate 1 hence -- ADV
# Added candidate words from : hence this brochure
# brochure
# Added candicate expression:  multi - disciplinary integrated method
# Added candidate words from : corruption
# corruption
# Added candidate words from : fruit
# fruit
# Added candicate expression:  inter - departmental working group
# Added candidate words from : the amendment
# amendment
# Added candidate words from : the laws
# laws
# Added candidate words from : bribery
# bribery
# Its members is not candidate 1 Its -- PRON
# Added candidate words from : Its members
# members
# their own expertise is not candidate 1 their -- PRON
# Added candidate words from : their own expertise
# expertise
# Added candicate expression:  new act
# 11 May is not candidate 1 11 -- NUM
# Added candidate words from : 11 May
# May
# Added candidate words from : Amendment
# Amendment
# Added candidate words from : the Law
# Law
# Added candidate words from : Bribery
# Bribery
# Added candidate words from : the doors
# doors
# Added candidate words from : consultation
# consultation
# Added candidate words from : all policy
# policy
# Added candicate expression:  Belgian government departments
# Added candidate words from : associations
# associations
# Added candidate words from : The following
# following
# Added candicate expression:  brief list
# Added candicate expression:  main partners
# Added candicate expression:  anti - corruption policy
# Added candidate words from : Justice
# Justice
# Added candidate words from : You
# Added candicate expression:  further information
# Belgian , European and international policy is not candidate 2 European -- ADJ, True
# Added candidate words from : Belgian , European and international policy
# Belgian
# policy
# Added candidate words from : corruption
# corruption
# the following websites is not candidate 1 following -- VERB
# Added candidate words from : the following websites
# websites
# Added candicate expression:  Federal Government Department
# Justice
# Federal Police
# Central Department is not candidate 1
#  -- SPACE
# Added candidate words from : Justice
# Federal Police
# Central Department
# Justice
# Federal
# Police
# Central
# Department
# Corruption
# Police is not candidate 1
#  -- SPACE
# Added candidate words from : Corruption
# Police
# Corruption
# Police
# web
# Federal Department is not candidate 1
#  -- SPACE
# Added candidate words from : web
# Federal Department
# web
# Federal
# Department
# Added candidate words from : the Budget
# Budget
# Added candidate words from : Bureau
# Bureau
# Added candicate expression:  Official Ethics
# Good Practice
# Federal Department is not candidate 1
#  -- SPACE
# Added candidate words from : Good Practice
# Federal Department
# Good
# Practice
# Federal
# Department
# Added candidate words from : Finance
# Finance
# ICC Belgium
# Federation is not candidate 1
#  -- SPACE
# Added candidate words from : ICC Belgium
# Federation
# ICC
# Belgium
# Federation
# Added candidate words from : Enterprises
# Enterprises
# Belgium
# Corporate governance is not candidate 1
#  -- SPACE
# Added candidate words from : Belgium
# Corporate governance
# Belgium
# governance
# Transparency International
# Transparency International Belgium
# World Bank
# Internet portal
# GRECO
# OECD
# UN corruption is not candidate 1
#  -- SPACE
# Added candidate words from : Transparency International
# Transparency International Belgium
# World Bank
# Internet portal
# GRECO
# OECD
# UN corruption
# Transparency
# International
# Transparency
# International
# Belgium
# World
# Bank
# Internet
# portal
# GRECO
# OECD
# UN
# corruption
# Added candidate words from : Corruption
# Corruption
# our company is not candidate 1 our -- PRON
# Added candidate words from : our company
# company
# ¦
# Preventing corruption is not candidate 1
#  -- SPACE
# Added candidate words from : ¦
# Preventing corruption
# ¦
# corruption
# Added candicate expression:  corporate life
# its central position is not candidate 1 its -- PRON
# Added candidate words from : its central position
# position
# Added candicate expression:  European Union
# Added candidate words from : Belgium
# Belgium
# Added candicate expression:  many years
# Added candicate expression:  firm line
# Added candidate words from : corruption
# corruption
# national and international transactions is not candidate 1 and -- CCONJ
# Added candidate words from : national and international transactions
# transactions
# Added candidate words from : this purpose
# purpose
# Added candicate expression:  major reform
# Added candidate words from : the end
# end
# Added candidate words from : the 1990s
# 1990s
# Added candicate expression:  affected aspects
# both the criminal liability is not candidate 1 both -- CCONJ
# Added candidate words from : both the criminal liability
# liability
# Added candicate expression:  legal persons
# Added candidate words from : the implications
# implications
# fiscal and criminal law is not candidate 1 and -- CCONJ
# Added candidate words from : fiscal and criminal law
# law
# Added candidate words from : action
# action
# Added candidate words from : corruption
# corruption
# Added candidate words from : a priority
# priority
# Added candicate expression:  Belgian government
# its National Security Plan is not candidate 1 its -- PRON
# Added candidate words from : its National Security Plan
# National
# Security
# Plan
# Added candidate words from : Corruption
# Corruption
# Added candicate expression:  various forms
# Added candicate expression:  severe penalties
# Added candidate words from : means
# means
# Added candidate words from : this brochure
# brochure
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : the awareness
# awareness
# Added candidate words from : companies
# companies
# Added candicate expression:  international markets
# Added candidate words from : goods
# goods
# Added candidate words from : services
# services
# Added candidate words from : the consequences
# consequences
# Added candidate words from : corruption
# corruption
# Added candicate expression:  Responsible management
# Added candicate expression:  clear definition
# Added candidate words from : what
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : this brochure
# brochure
# Added candidate words from : the awareness
# awareness
# Added candicate expression:  commercial players
# Added candidate words from : them
# Added candidate words from : the risks
# risks
# their business contacts is not candidate 1 their -- PRON
# Added candidate words from : their business contacts
# business
# contacts
# Added candidate words from : What
# Added candidate words from : corruption
# corruption
# Added candidate words from : Corruption
# Corruption
# Added candidate words from : a manifestation
# manifestation
# Added candidate words from : criminality
# criminality
# Added candidate words from : It
# Added candidate words from : companies
# companies
# Added candidate words from : society
# society
# Added candidate words from : It
# Added candidate words from : distortion
# distortion
# Added candidate words from : competition
# competition
# Added candidate words from : investors
# investors
# Added candicate expression:  further development
# Added candicate expression:  sound companies
# Added candidate words from : Corruption
# Corruption
# morally reprehensible and undermines trust is not candidate 1 morally -- ADV
# Added candidate words from : morally reprehensible and undermines trust
# undermines
# trust
# Added candidate words from : society
# society
# Added candidate words from : democracy
# democracy
# Added candicate expression:  business community
# Added candidate words from : it
# Added candicate expression:  main obstacle
# Added candidate words from : investment
# investment
# Added candicate expression:  certain countries
# Added candicate expression:  longer term
# Added candidate words from : corruption
# corruption
# Added candidate words from : costs
# costs
# Added candidate words from : the community
# community
# Added candidate words from : companies
# companies
# Added candidate words from : it
# Added candidate words from : a deterioration
# deterioration
# Added candidate words from : quality
# quality
# Added candidate words from : safety
# safety
# a natural or a legal person is not candidate 1 or -- CCONJ
# Added candidate words from : a natural or a legal person
# person
# Added candidate words from : corruption
# corruption
# Added candidate words from : the soliciting
# soliciting
# Added candidate words from : acceptance
# acceptance
# Added candidate words from : receipt
# receipt
# Added candidate words from : any form
# form
# Added candidate words from : advantage
# advantage
# Added candicate expression:  official context
# Added candidate words from : acceptance
# acceptance
# a given practice is not candidate 1 given -- VERB
# Added candidate words from : a given practice
# practice
# Added candidate words from : behaviour
# behaviour
# Added candidate words from : It
# Added candidate words from : the offering
# offering
# Added candidate words from : granting
# granting
# Added candicate expression:  such advantage
# Added candidate words from : a person
# person
# Added candicate expression:  such behaviour
# Added candidate words from : The law
# law
# Added candicate expression:  Belgian individuals
# Added candidate words from : companies
# companies
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : no distinction
# distinction
# national , international and foreign office-holders is not candidate 1 and -- CCONJ
# Added candidate words from : national , international and foreign office-holders
# office
# holders
# Added candidate words from : It
# Added candidate words from : no difference
# difference
# Added candidate words from : the bribery
# bribery
# Added candidate words from : place
# place
# Added candidate words from : intermediaries
# intermediaries
# Added candidate words from : the advantage
# advantage
# Added candidate words from : oneself
# Added candicate expression:  third party
# Added candidate words from : It
# Added candidate words from : it
# Added candidate words from : the public
# public
# Added candicate expression:  private sector
# Both the person is not candidate 1 Both -- CCONJ
# Added candidate words from : Both the person
# person
# Added candicate expression:  such advantages
# Added candidate words from : the recipient
# recipient
# Added candidate words from : corruption
# corruption
# Added candicate expression:  Belgian law
# both private and public bribery is not candidate 1 both -- CCONJ
# Added candidate words from : both private and public bribery
# bribery
# both active and passive bribery is not candidate 1 both -- CCONJ
# Added candidate words from : both active and passive bribery
# bribery
# Added candicate expression:  other words
# Added candidate words from : corruption
# corruption
# Added candicate expression:  various levels
# Added candicate expression:  various forms
# Added candidate words from : All these forms
# forms
# Added candidate words from : corruption
# corruption
# Added candicate expression:  criminal offences
# Added candidate words from : Belgium
# Belgium
# Added candidate words from : fact
# fact
# Added candicate expression:  incidental condition
# Added candicate expression:  private corruption
# Added candidate words from : it
# Added candidate words from : place
# place
# Added candicate expression:  prior knowledge
# Added candidate words from : the authorisation
# authorisation
# Added candidate words from : the case
# case
# Added candidate words from : directors
# directors
# Added candicate expression:  general assembly
# Added candicate expression:  Belgian Criminal Code
# two chapters is not candidate 1 two -- NUM
# Added candidate words from : two chapters
# chapters
# Added candidate words from : importance
# importance
# Added candidate words from : corruption
# corruption
# Added candidate words from : They
# Added candicate expression:  Criminal Code Articles
# 246 ff is not candidate 1 246 -- NUM
# Added candidate words from : 246 ff
# ff
# Added candidate words from : .
# .
# Added candidate words from : which
# Added candicate expression:  public bribery
# Added candidate words from : 504bis
# 504bis
# Added candidate words from : ter
# ter
# Added candicate expression:  private bribery
# Added candidate words from : Penalties
# Penalties
# six months is not candidate 1 six -- NUM
# Added candidate words from : six months
# months
# three years imprisonment is not candidate 1 three -- NUM
# Added candidate words from : three years imprisonment
# years

# %%
results
